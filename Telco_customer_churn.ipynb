# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Intro

# %% [markdown]
# #### Telco_customer_churn is set that comes from https://www.kaggle.com/blastchar/telco-customer-churn. As the name indicate, the main goal of this dataset is to predict churn of customer. It consists 21 variables, which informates about:
# #### - demografic info abouts customer

# %%
path = 'Telco_customer_churn.csv'
df = pd.read_csv(path)

# %%
df.head(5) #to make sure that data import correctly
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Gender
# ### Gender variable indicates the sex of customoer. There can be distinguished two values of that variable: Female and Male. In the dataset there is nearly 50:50 divide. Based on the countplot any of the value has no signficant advantage on another.

# %%
plt.figure(figsize=(18,8))
ax = sns.countplot(x = 'gender', hue = 'Churn', data = df, palette = 'bright')
plt.title('Number of customers by gender')
plt.xlabel('Gender')
plt.ylabel('Count')

for p in ax.patches:
     ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+10))

plt.show()

# %% [markdown]
# ## SeniorCitizen
# ### SeniorCtizen variable indicates if the customer is an old age pensioner. The general amount of senior citizens is equal to 1142, what means by doing simple maths that there are 5901 persons who are not reached the retirement age yet.

# %%
plt.figure(figsize = (18,8))
ax = sns.countplot(x = 'SeniorCitizen', hue = 'Churn', data = df)
plt.title('Numbers of senior citizens')
plt.xlabel('Senior citizen')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+10))

plt.show()

# %% [markdown]
# ## Partner
# ### Partner variable indicates if the customer posses or not posses partner. In general there are 3402 customers, who posses partners and 3641 who not posses.  As we can see from the barplot below the amount of people who belongs to churn is much higher in the group of customers not possesing partners. It is exactly 49,16% to 24,48%.

# %%
plt.figure(figsize = (18,8))
ax = sns.countplot(x = 'Partner', hue = 'Churn', data = df)
plt.title('Number of customers possesing/not possesing partners')
plt.xlabel('Does the customer posses partner?')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+10))

plt.show()

# %% [markdown]
# ## Dependents
# ### Dependents variable indicates if the customer is dependent or not. Data shows that nearly one third of sample is dependent. There is also definetely lower rate of Churn in that group (15,45%) compared to not dependent where 31,28% are Churn.

# %%
plt.figure(figsize = (18,8))
ax = sns.countplot(x = 'Dependents', hue = 'Churn', data = df)
plt.title('Number of customers that are dependents or not')
plt.xlabel('Does the customer is dependent?')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+10))

plt.show()

# %% [markdown]
# ## Tenure
# ### Tenure variable indicates the number of months that customer decide to stay witho company. Countplot below informs that the highest rate of Churn is in the first month, and that is the only month, where Churn are higher than not Churn. There is also significant trend that shows, that the greater is the number of months is when customer stay with company, there is the lower possibility that he will decide to leave.

# %%
plt.figure(figsize = (100,8))
ax = sns.countplot(x = 'tenure', hue = 'Churn', data = df)
plt.title('Number of months the customer has stayed with the company')
plt.xlabel('Number of months')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x(), p.get_height()+1))

plt.show()

# %%
plt.figure(figsize = (15,8))
ax = sns.countplot(x = 'PhoneService', hue = 'Churn', data = df)
plt.title('Whether the customer has a phone service or not')
plt.xlabel('Phone Service')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+25))

plt.show()

# %%
plt.figure(figsize = (15,8))
ax = sns.countplot(x = 'MultipleLines', hue = 'Churn', data = df)
plt.title('Number of customer that has multiple lines or not')
plt.xlabel('Multiple Lines')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+25))

plt.show()

# %%
plt.figure(figsize = (15,8))
ax = sns.countplot(x = 'InternetService', hue = 'Churn', data = df)
plt.title('Number of customers by internet service provider')
plt.xlabel('Internet Service provider')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+25))

plt.show()

# %%
plt.figure(figsize = (15,8))
ax = sns.countplot(x = 'OnlineSecurity', hue = 'Churn', data = df)
plt.title('Number of customers by internet service provider')
plt.xlabel('Online Security')
plt.ylabel('Count')

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+ 0.15, p.get_height()+25))

plt.show()
